# %%
dbutils.widgets.removeAll()
dbutils.widgets.dropdown(name = 'load_type', defaultValue= 'init', choices= ['init', 'delta'], label = 'load type')
load_type1 = dbutils.widgets.get('load_type')
print(load_type1)
# Out:
# init

# %% [markdown]
# ### Metadata Create

# %%
# %run /Users/rsbansode2000@gmail.com/Project/cricket/metadata/cricket01
# Out:
# Out[155]: True
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %run /Users/rsbansode2000@gmail.com/Project/cricket/metadata/gold/cricket01_gold
# Out:
# Out[156]: True
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Bronze notebook

# %%
# %run /Users/rsbansode2000@gmail.com/Project/cricket/bronze/cricket01_bronze $load_type={load_type}
# Out:
# Load Type : {load_type}

# %% [markdown]
# ### Silver Notebook

# %%
# %run /Users/rsbansode2000@gmail.com/Project/cricket/silver/cricket01_silver $load_type=load_type
# Out:
# Load Type : load_type

# %% [markdown]
# ### Gold Notebook

# %%
# %run /Users/rsbansode2000@gmail.com/Project/cricket/gold/cricket01_gold $load_type={load_type}

# %% [markdown]
# ### Business Trans

# %%
# %run /Users/rsbansode2000@gmail.com/Project/cricket/business-trans/busines_trans_test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
